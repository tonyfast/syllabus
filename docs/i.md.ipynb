# %% [markdown]
# # writing
#
# the goal of writing is to bring meaning to the abstract.
#
# NOTE
# : this needs an introduction about the arc of the course.
#
# 1. writing for fun and pleasure
# 2. our first introduction into literate programs.
# 3. writing for ourselves.
# 4. bounding ideas and time
# 5. homeworks

# %% [markdown]
# ![image.png](attachment:ec39e499-1a6c-44b6-988a-cd4fafcca7ae.png)

# %% [markdown]
# ## note from prior course
#
# this part of the course needs to:
#
# *  include more women
#   * consider barbara kruger, jane jacobs, toni morrison, annette vee
# *  discuss outlining
# * omit some outline stuff that wasn't used
# * describe different writing interfaces
#
# for the exercises, we will have a few notebooks containing only code, and folks can practice adding narrative to the code. examples will include python, css, html, markdown.
#
# ![](https://dmdlnu87i51n1.cloudfront.net/v1/uk/ckq9etsz4000o3h5qljy0mkur/0x0:1600x849/undefinedxundefined/336_ex_jf_kruger_bk_forever3_press_yes_rt.jpg) https://www.theartnewspaper.com/interview/barbara-kruger-thank-god-i-m-an-artist

# %%
# %%
# ## writing for pleasure
#
# we are going to relearn to write so that would can find joy and pleasure in our writing.
# we'll be introduced to a new style of writing, literate programming, that opens up
# the possibilities of meaning in literature.
#
# ---
# ---
#
# > There is, finally between science and literature, a third margin
# which science must reconquer, that of pleasure.
#
# >> * [roland barthes] [science vs literature]
#
# ---
#
# > My hope is that the ability to make explanations more natural will cause
# > more programmers to discover the joys of literate programming,
# > because I believe it’s quite a pleasure to combine verbal and mathematical skills;
# > but perhaps I’m hoping for too much.
#
# >> * [donald knuth] [literate programming]
#
# ---
# ---
# Out:
# <h2>writing for pleasure</h2>
# <p>we are going to relearn to write so that would can find joy and pleasure in our writing.
# we'll be introduced to a new style of writing, literate programming, that opens up
# the possibilities of meaning in literature.</p>
# <hr />
# <hr />
# <blockquote>
# <p>There is, finally between science and literature, a third margin
# which science must reconquer, that of pleasure.</p>
# </blockquote>
# <blockquote>
# <blockquote>
# <ul>
# <li>[roland barthes] [science vs literature]</li>
# </ul>
# </blockquote>
# </blockquote>
# <hr />
# <blockquote>
# <p>My hope is that the ability to make explanations more natural will cause
# more programmers to discover the joys of literate programming,
# because I believe it’s quite a pleasure to combine verbal and mathematical skills;
# but perhaps I’m hoping for too much.</p>
# </blockquote>
# <blockquote>
# <blockquote>
# <ul>
# <li>[donald knuth] [literate programming]</li>
# </ul>
# </blockquote>
# </blockquote>
# ...

# %%
# %%
# ## discussion
#
# >> > celebrate and share a piece of media of that you've enjoyed learning from.
#
# >> > What makes writing unfun?
# Out:
# <h2>discussion</h2>
# <blockquote>
# <blockquote>
# <blockquote>
# <p>celebrate and share a piece of media of that you've enjoyed learning from.</p>
# </blockquote>
# </blockquote>
# </blockquote>
# <blockquote>
# <blockquote>
# <blockquote>
# <p>What makes writing unfun?</p>
# </blockquote>
# </blockquote>
# </blockquote>

# %% [markdown]
# ## literate programming

# %%
# %%
# literate programs treat programs as essays where literary and computational excellence are paramount.
# they are implicitly multi-lingual documents containing at least two programming languages.
#
# * __tangle__ narrative into code
# * __weave__ code into narrative
#
# &nbsp;
#
#     (hommage :=
# ```dot
# digraph {
#     rankdir=LR
#     WEB->TEX[label=WEAVE]
#     TEX->DVI[label=TEX]
#     WEB->PAS[label=TANGLE]
#     PAS->REL[label=PASCAL]}
# ```
#     )
#
#
# > with html, we can introduce different language representations using the [`lang`](https://developer.mozilla.org/en-US/docs/Web/HTML/Global_attributes/lang) attribute.
# Out:
# <p>literate programs treat programs as essays where literary and computational excellence are paramount.
# they are implicitly multi-lingual documents containing at least two programming languages.</p>
# <ul>
# <li><strong>tangle</strong> narrative into code</li>
# <li><strong>weave</strong> code into narrative</li>
# </ul>
# <p> </p>
# <pre><code>(hommage :=
# </code></pre>
# <pre><code class="dot"><div class="highlight" style="background: #f8f8f8"><pre style="line-height: 125%;"><span></span><span style="color: #008000; font-weight: bold">digraph</span><span style="color: #bbbbbb"> </span>{
# <span style="color: #bbbbbb">    </span><span style="color: #687822">rankdir</span>=<span style="color: #BA2121">LR</span><span style="color: #bbbbbb"> </span>
# ...

# %%
# %%
# ### literate computing in computational notebooks
#
#     md=\
# ```dot
# digraph {rankdir=LR MD->HTML[label=WEAVE]}
# ```
#     nb=\
# ```dot
# digraph {rankdir=LR IPYNB->JSON[label=WEAVE] JSON->HTML[label=nbcovert]
#         IPYNB->JSON[label=TANGLE] JSON->PY[label=nbcovert]}
# ```
#
#     display(hommage, md, nb)
# Out:
# 'digraph {\n    rankdir=LR \n    WEB->TEX[label=WEAVE] \n    TEX->DVI[label=TEX] \n    WEB->PAS[label=TANGLE] \n    PAS->REL[label=PASCAL]}\n'
# 'digraph {rankdir=LR MD->HTML[label=WEAVE]}\n'
# 'digraph {rankdir=LR IPYNB->JSON[label=WEAVE] JSON->HTML[label=nbcovert] \n        IPYNB->JSON[label=TANGLE] JSON->PY[label=nbcovert]}\n'
# <h3>literate computing in computational notebooks</h3>
# <pre><code>md=\
# </code></pre>
# ...

# %%
the moral principle behind literate programming is that programs should acheive literary excellence.



>  By coining the phrase “literate programming,” I am imposing a moral commitment
on everyone who hears the term; surely nobody wants
to admit writing an illiterate program.
>> * [donald knuth] [literate programming]

in traditional non-literate programming we measure the computational quality of the work, 
and in literature we measure the literary qualities. any attempt to measure the 
quality of code in traditional literature or the literary qualities of code in programs
is ill-posed outside of the literate programming framework.

the practice of literate programming unifies much of our work as writing or composition.
we measure all works from both their literary and computational qualities. in literate programming,
narrative and code cooperate to bring meaning to otherwise abstract objects like functions, classes,
or data. forevermore, the narrative and code are inextricably linked, neither language takes priority rather
the composition of cooperative languages.
# Out:
# the moral principle behind literate programming is that programs should acheive literary excellence.
#
#
#
# >  By coining the phrase “literate programming,” I am imposing a moral commitment
# on everyone who hears the term; surely nobody wants
# to admit writing an illiterate program.
# >> * [donald knuth] [literate programming]
#
# in traditional non-literate programming we measure the computational quality of the work,
# and in literature we measure the literary qualities. any attempt to measure the
# quality of code in traditional literature or the literary qualities of code in programs
# is ill-posed outside of the literate programming framework.
#
# the practice of literate programming unifies much of our work as writing or composition.
# we measure all works from both their literary and computational qualities. in literate programming,
# narrative and code cooperate to bring meaning to otherwise abstract objects like functions, classes,
# ...

# %%
### a little history of [literate programming]

[literate programming] was presented in 1984 by [Donald Knuth].

* __pascal__ programming language
* __tex__ document language

[literate programming]: http://www.literateprogramming.com/knuthweb.pdf
# Out:
# ### a little history of [literate programming]
#
# [literate programming] was presented in 1984 by [Donald Knuth].
#
# * __pascal__ programming language
# * __tex__ document language
#
# [literate programming]: http://www.literateprogramming.com/knuthweb.pdf

# %%
https://en.m.wikipedia.org/wiki/Literate_programming
# Out:
#         <iframe
#             width="100%"
#             height="600"
#             src="https://en.m.wikipedia.org/wiki/Literate_programming"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
### modern literate programming

* __python__ programming language
* __markdown__ document language

it is clear we won't be writing programs in pascal so we are going to take a modern riff on literate programming.

#### in markdown

markdown is the best language, it never lets you fail, it just does unexpected things.
in our course, we'll focus on __markdown__ as the document language. tools like __tex__ and __rst__
border on domain specific languages, and can be wrought with failure.

markdown is a tool for literate programming because it considers all possible programming lanuages
within its specificiation

{{md}}

#### in notebooks

notebooks are an ideal substrate for literate programs. it promotes the interleaving of __markdown__
and code cells to bring meaning to code.

{{nb}}
# Out:
# ### modern literate programming
#
# * __python__ programming language
# * __markdown__ document language
#
# it is clear we won't be writing programs in pascal so we are going to take a modern riff on literate programming.
#
# #### in markdown
#
# markdown is the best language, it never lets you fail, it just does unexpected things.
# in our course, we'll focus on __markdown__ as the document language. tools like __tex__ and __rst__
# border on domain specific languages, and can be wrought with failure.
#
# markdown is a tool for literate programming because it considers all possible programming lanuages
# within its specificiation
#
# <img src="data:image/svg+xml;base64,<?xml version="1.0" encoding="UTF-8" standalone="no"?><!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
#  "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd"><!-- Generated by graphviz version 2.42.3 (20191010.1750)
# ...

# %% [markdown]
# ## you are your first audience
#
# you the writer contain multitudes, you have many audiences, and most attempts
# to write to an idealized audience will hamper the connection between you and your work.
#
# ### guidance for you, your first audience
#
# while writing,
#     write for yourself,
#         write something you want to read,
#             write the documentation you think is needed,
#                 write the blog post you wish was written.

# %% [markdown]
# ## bounding your ideas
#
# a good check for bounding your work is does it __restart and run all__? we will not impose this constraint
# on our essays just yet. a writer always knows there is more they want to write, with time, you'll get there. for now, try to write about one small idea at a time, if you start adding ideas as if they are needed.

# %%
## until next time

### things to think about

* what do you need to write?
* what are some small things you've

### writings prompts

* write a document containing code and narrative in a notebook or file.

  ### examples
  
  * [sharing documents] on google or github
  * [about me]
  
* share your document as a gist, repo, or colab notebook

  ### examples
  
* begin working on your github readme profile

  ### examples
  
  * [monica]
  * [tonyfast]
  * [simonw]
# Out:
# ## until next time
#
# ### things to think about
#
# * what do you need to write?
# * what are some small things you've
#
# ### writings prompts
#
# * write a document containing code and narrative in a notebook or file.
#
#   ### examples
#
#   * [sharing documents] on google or github
#   * [about me]
#
# * share your document as a gist, repo, or colab notebook
#
#   ### examples
#
# * begin working on your github readme profile
#
#   ### examples
#
#   * [monica]
#   * [tonyfast]
#   * [simonw]

# %% [markdown]
# ## background
#
# this section includes background, and links, to concepts that help to be familiar with when learning to write literate programs.
#
# ### markdown syntax
#
# for the purposes of this course we all program in markdown. markdown is our programming language. it lets us combine all programming languages into one document.
#
# #### widespread adoption
#
# > we will discuss the readme at length in this program and this cultural adoption of `readme` markdown files as a convention.
#
# ### literate programming
#
#
#
# ### computational notebook interfaces
#
# ### computational notebook formats

# %% [markdown]
# ## writing things you'll want to read
#
# it is hard to know our audience, but we can learn about ourselves. we tasked with creating a work for these programs focus on writing what you may want to read in the future. be your best audience.
